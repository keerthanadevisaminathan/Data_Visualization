# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanadevisaminathan/Data_Visualization/blob/main/bytsasmnt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('bytsasmnt.csv')
data
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp         0
# Participant_ID    0
# Gender            4
# Nationality       0
# Age               0
# Food              0
# Juice             0
# Dessert           0
# dtype: int64

# %%
data.dtypes
# Out:
# Timestamp         object
# Participant_ID    object
# Gender            object
# Nationality       object
# Age                int64
# Food              object
# Juice             object
# Dessert           object
# dtype: object

# %%
data['Gender'].value_counts()
# Out:
# Female    165
# Male      119
# Name: Gender, dtype: int64

# %%
data['Gender'].replace(np.nan,'Female',inplace=True)

# %%
data
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp         0
# Participant_ID    0
# Gender            0
# Nationality       0
# Age               0
# Food              0
# Juice             0
# Dessert           0
# dtype: int64

# %%
data.columns.tolist()
# Out:
# ['Timestamp',
#  'Participant_ID',
#  'Gender',
#  'Nationality',
#  'Age',
#  'Food',
#  'Juice',
#  'Dessert']

# %%
data.dtypes
# Out:
# Timestamp         object
# Participant_ID    object
# Gender            object
# Nationality       object
# Age                int64
# Food              object
# Juice             object
# Dessert           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Timestamp       288 non-null    object
#  1   Participant_ID  288 non-null    object
#  2   Gender          288 non-null    object
#  3   Nationality     288 non-null    object
#  4   Age             288 non-null    int64
#  5   Food            288 non-null    object
#  6   Juice           288 non-null    object
#  7   Dessert         288 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 18.1+ KB

# %%
data.describe()
# Out:
#               Age
# count  288.000000
# mean    30.597222
# std     11.180383
# min      8.000000
# 25%     24.000000
# 50%     28.000000
# 75%     36.250000
# max     80.000000

# %%
data.describe(include='object')
# Out:
#                           Timestamp Participant_ID  Gender Nationality  \
# count                           288            288     288         288
# unique                          285            288       2          27
# top     2019/05/08 1:16:11 AM GMT+8         FPS001  Female      Indian
# freq                              2              1     169         241
#
#                     Food        Juice Dessert
# count                288          288     288
# unique                 2            2       3
# top     Traditional food  Fresh Juice   Maybe
# freq                 238          256     122

# %%
data.describe(include='all')
# Out:
#                           Timestamp Participant_ID  Gender Nationality  \
# count                           288            288     288         288
# unique                          285            288       2          27
# top     2019/05/08 1:16:11 AM GMT+8         FPS001  Female      Indian
# freq                              2              1     169         241
# mean                            NaN            NaN     NaN         NaN
# std                             NaN            NaN     NaN         NaN
# min                             NaN            NaN     NaN         NaN
# 25%                             NaN            NaN     NaN         NaN
# 50%                             NaN            NaN     NaN         NaN
# 75%                             NaN            NaN     NaN         NaN
# max                             NaN            NaN     NaN         NaN
#
#                Age              Food        Juice Dessert
# ...

# %%
data
# Out:
#                         Timestamp Participant_ID  Gender Nationality  Age  \
# 0     2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1     2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2     2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3     2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4     2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
# ..                            ...            ...     ...         ...  ...
# 283   2019/05/10 9:24:00 AM GMT+8         FPS284    Male      Indian   27
# 284   2019/05/10 9:32:54 AM GMT+8         FPS285    Male      Indian   24
# 285  2019/05/10 12:09:17 PM GMT+8         FPS286    Male      Indian   25
# 286  2019/05/10 12:52:17 PM GMT+8         FPS287    Male      Indian   27
# 287  2019/05/10 12:55:42 PM GMT+8         FPS288    Male      Indian   27
#
#                  Food              Juice Dessert
# ...

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-68-53fe516a88e7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
a=data.corr()
print(a)
# Out:
#      Age
# Age  1.0
# <ipython-input-51-2019318a44c2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a=data.corr()

# %%
import pandas as pd
import matplotlib.pyplot as plt
Gender = data['Gender']
Nationality = data['Nationality']
indian_counts = data[data['Nationality'] == 'Indian']['Gender'].value_counts()
print("Number of males and females who are Indians:")
print(indian_counts)
indian_counts.plot(kind='bar', color='b')
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Number of Males and Females Who Are Indians")
plt.show()
# Out:
# Number of males and females who are Indians:
# Female    152
# Male       89
# Name: Gender, dtype: int64

# %%
Age = data['Age']
food = data['Food']
Juice=data['Juice']
plt.scatter(Juice,Nationality,marker='*', s=75 , color='green')
plt.xlabel('Juice')
plt.ylabel('Nationality')
plt.title('Scatter Plot of Age and Food')
plt.grid(True)
plt.show()

# %%
plt.hist(Age, bins=100)
plt.title("Histogram")
plt.show()

# %%
plt.plot(Age)
plt.title("Plot Age")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
Gender = data['Gender']
Nationality = data['Nationality']
counts = data[data['Age'] > 30]['Gender'].value_counts()
print("Number of males and females above the age 30:")
print(counts)
counts.plot(kind='box', color='c')
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Number of Males and Females above the age 30")
plt.show()
# Out:
# Number of males and females above the age 30:
# Female    88
# Male      24
# Name: Gender, dtype: int64
